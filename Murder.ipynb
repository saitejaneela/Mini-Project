# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Telmurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.tick_params(axis='x', which='major', labelsize=8)
plt.savefig("TelMurder.png")
plt.title('Telangana Murder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('mahamurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("MaharastraMurder.png")
plt.title('Maharastra Murder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('keralamurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("keralamurder.png")
plt.title('Kerala Murder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Tamilmurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("TamilnaduMurder.png")
plt.title('TamilnaduMurder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Andmurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("AndMurder.png")
plt.title('AndrapradeshMurder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Biharmurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("Biharmurder.png")
plt.title('Bihar Murder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Delhimurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("Delhimurder.png")
plt.title('Delhi Murder')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Karnamurder.csv')
left=dataset.iloc[:,0]
height=dataset.iloc[:,1]
tick_label=dataset.iloc[:,2]
dataset.iloc[0,:]
plt.bar(left, height, tick_label = tick_label,width = 0.8, color = ['red', 'green'])
plt.xlabel('Years')
plt.ylabel('Murder')
plt.savefig("Karnamurder.png")
plt.title('Karnataka Murder')
plt.show()
